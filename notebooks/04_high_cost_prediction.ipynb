# %% [markdown]
# # 04 High-Cost Prediction
#
# Train and evaluate next-year high-cost beneficiary models.

# %%
import duckdb

con = duckdb.connect('../data/processed/desynpuf.duckdb', read_only=True)
model_df = con.execute('SELECT * FROM gold_high_cost_prediction_dataset').df()
model_df[['input_year', 'target_year', 'high_cost_next_year']].head()

# %% [markdown]
# For the scripted training workflow, run `make train` from the repository root.
