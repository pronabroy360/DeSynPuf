# %% [markdown]
# # 03 Feature Engineering
#
# Inspect the patient-year feature table used for analytics and modeling.

# %%
import duckdb

con = duckdb.connect('../data/processed/desynpuf.duckdb', read_only=True)
features = con.execute('SELECT * FROM gold_patient_year_summary LIMIT 1000').df()
features.head()

# %%
features.describe(include='all')
