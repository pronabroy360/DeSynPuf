# %% [markdown]
# # 02 Claims EDA
#
# Explore synthetic cost and utilization patterns by year and claim type.

# %%
from pathlib import Path
import duckdb

con = duckdb.connect('../data/processed/desynpuf.duckdb', read_only=True)
con.execute('SELECT * FROM gold_patient_cost_summary ORDER BY year').df()

# %%
con.execute('SELECT * FROM gold_patient_utilization_summary ORDER BY year').df()
